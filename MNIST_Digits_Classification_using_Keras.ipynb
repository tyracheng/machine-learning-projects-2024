# %% [markdown]
# <a href="https://colab.research.google.com/github/tyracheng/machine-learning-projects-2024/blob/main/MNIST_Digits_Classification_using_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Numbers handwriting detection model inspired by 3Blue1Brown on Youtube. Basically, the model learns to recognize which number each image represents. So it's like training a computer to read messy human handwriting and still get it right.
#
# - Tyra Cheng

# %%
from google.colab import drive
drive.mount('/content/drive')
folder_url_1 = 'content/drive/My Drive/Set 1'
folder_url_2 = 'content/drive/My Drive/Set 2'

class CustomImageDataset(Dataset):
    def __init__(self, image_dir, transform=None):
        self.image_dir = image_dir
        self.transform = transform
        self.image_labels = []
        self.image_files = []

        for file_name in os.listdir(image_dir):
            if file_name.endswith(('png', 'jpg', 'jpeg')):
                label = int(file_name.split('-')[0])
                self.image_labels.append(label)
                self.image_files.append(file_name)

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.image_files[idx])
        image = Image.open(img_path).convert("RGB")
        label = self.image_labels[idx]

        if self.transform:
            image = self.transform(image)

        return image, label
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_2570/844928651.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3 folder_url_1 = 'content/drive/My Drive/Set 1'
#       4 folder_url_2 = 'content/drive/My Drive/Set 2'
#       5
#
# /usr/local/lib/python3.13/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.13/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# ...

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from matplotlib import pyplot as plt
import seaborn as sn #simplifies informative statistical graphics, helps us monitor training progress
#x X

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
X_train = X_train/ 255 #normalize
X_test = X_test/ 255

# %%
index = 0
plt.imshow(X_train[index], cmap = plt.cm.binary)
print(y_train[index])

# %%
X_train_flat = X_train.reshape(len(X_train), (28*28))
X_test_flat = X_test.reshape(len(X_test), (28*28))

# %%
X_train_flat.shape

# %%
model = keras.Sequential([
    keras.layers.Dense(128, input_shape = (784,), activation = 'relu'),
    keras.layers.Dense(64, activation = 'sigmoid'),
    keras.layers.Dense(32, activation = 'sigmoid'),
    keras.layers.Dense(10, activation = 'softmax'),
])

model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

model.fit(X_train_flat, y_train, epochs = 5)

# %%
model.evaluate(X_test_flat, y_test)

# %%
y_pred = model.predict(X_test_flat)
y_pred_labels = [np.argmax(i) for i in y_pred]

# %% [markdown]
# Graph

# %%
from sklearn.metrics import confusion_matrix, classification_report

from sklearn.metrics import confusion_matrix
import seaborn as sns

# Generate the confusion matrix
cm = confusion_matrix(y_test, y_pred_labels)

# Plot the confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Yellows')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

from sklearn.metrics import classification_report

# Print the classification report
print(classification_report(y_test, y_pred_labels))

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
from PIL import Image
import numpy as np

# Load the image
image_path = "image_set_1/0-1.png"
img = Image.open(image_path).convert('L')  # Convert to grayscale

# Preprocess the image
img = img.resize((28, 28))  # Resize to the input size required by your model
img_array = image.img_to_array(img)
img_array = img_array / 255.0  # Normalize to [0, 1]
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

# Load your Keras model
model_path = "/content/drive/1tLNczRtKmAp6msCRQ1uuV5h51ZeUV64o"  # Update this to your model's path
model = load_model(model_path)

# Make prediction
predictions = model.predict(img_array)
predicted_class = np.argmax(predictions, axis=1)[0]
print(f"This is probably {predicted_class}")
